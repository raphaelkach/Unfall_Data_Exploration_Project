# %%
import pandas as pd

# %%
df = pd.read_csv('./data/raw/FARS_2022_National/accident.csv', encoding='ISO-8859-1')

# %%
#Ausgabe des nicht bereinigten Datensatzes der Zeilen und Spalten

print(f'Anzahl der Zeilen: {df.shape[0]}') # Summe der Zeilen
print(f'Anzahl der Spalten: {df.shape[1]}') # Summe der Spalten

#Gibt es doppelte Zeilen?
print(f'Duplikate in Datensatz: {df.duplicated().sum()}')
# Out:
# Anzahl der Zeilen: 39221
# Anzahl der Spalten: 80
# Duplikate in Datensatz: 0

# %%
# Welche Spalten habe ich?
print(df.columns)
# Out:
# Index(['STATE', 'STATENAME', 'ST_CASE', 'PEDS', 'PERNOTMVIT', 'VE_TOTAL',
#        'VE_FORMS', 'PVH_INVL', 'PERSONS', 'PERMVIT', 'COUNTY', 'COUNTYNAME',
#        'CITY', 'CITYNAME', 'MONTH', 'MONTHNAME', 'DAY', 'DAYNAME', 'DAY_WEEK',
#        'DAY_WEEKNAME', 'YEAR', 'HOUR', 'HOURNAME', 'MINUTE', 'MINUTENAME',
#        'TWAY_ID', 'TWAY_ID2', 'ROUTE', 'ROUTENAME', 'RUR_URB', 'RUR_URBNAME',
#        'FUNC_SYS', 'FUNC_SYSNAME', 'RD_OWNER', 'RD_OWNERNAME', 'NHS',
#        'NHSNAME', 'SP_JUR', 'SP_JURNAME', 'MILEPT', 'MILEPTNAME', 'LATITUDE',
#        'LATITUDENAME', 'LONGITUD', 'LONGITUDNAME', 'HARM_EV', 'HARM_EVNAME',
#        'MAN_COLL', 'MAN_COLLNAME', 'RELJCT1', 'RELJCT1NAME', 'RELJCT2',
#        'RELJCT2NAME', 'TYP_INT', 'TYP_INTNAME', 'REL_ROAD', 'REL_ROADNAME',
#        'WRK_ZONE', 'WRK_ZONENAME', 'LGT_COND', 'LGT_CONDNAME', 'WEATHER',
#        'WEATHERNAME', 'SCH_BUS', 'SCH_BUSNAME', 'RAIL', 'RAILNAME', 'NOT_HOUR',
# ...

# %%
df.rename(columns={
    'STATE': 'State',
    'STATENAME': 'StateName',
    'ST_CASE': 'CaseNumber',
    'PEDS': 'Pedestrians',
    'PERNOTMVIT': 'NonMotorizedPersons',
    'VE_TOTAL': 'TotalVehicles',
    'VE_FORMS': 'VehicleForms',
    'PVH_INVL': 'InvolvedVehicles',
    'PERSONS': 'Persons',
    'PERMVIT': 'MotorizedPersons',
    'COUNTY': 'County',
    'COUNTYNAME': 'CountyName',
    'CITY': 'City',
    'CITYNAME': 'CityName',
    'MONTH': 'Month',
    'MONTHNAME': 'MonthName',
    'DAY': 'Day',
    'DAYNAME': 'DayName',
    'DAY_WEEK': 'DayOfWeek',
    'DAY_WEEKNAME': 'DayOfWeekName',
    'YEAR': 'Year',
    'HOUR': 'Hour',
    'HOURNAME': 'HourName',
    'MINUTE': 'Minute',
    'MINUTENAME': 'MinuteName',
    'TWAY_ID': 'TrafficwayID',
    'TWAY_ID2': 'TrafficwayID2',
    'ROUTE': 'Route',
    'ROUTENAME': 'RouteName',
    'RUR_URB': 'RuralUrban',
    'RUR_URBNAME': 'RuralUrbanName',
    'FUNC_SYS': 'FunctionalSystem',
    'FUNC_SYSNAME': 'FunctionalSystemName',
    'RD_OWNER': 'RoadOwner',
    'RD_OWNERNAME': 'RoadOwnerName',
    'NHS': 'NHS',
    'NHSNAME': 'NHSName',
    'SP_JUR': 'SpecialJurisdiction',
    'SP_JURNAME': 'SpecialJurisdictionName',
    'MILEPT': 'Milepoint',
    'MILEPTNAME': 'MilepointName',
    'LATITUDE': 'Latitude',
    'LATITUDENAME': 'LatitudeName',
    'LONGITUD': 'Longitude',
    'LONGITUDNAME': 'LongitudeName',
    'HARM_EV': 'HarmfulEvent',
    'HARM_EVNAME': 'HarmfulEventName',
    'MAN_COLL': 'CollisionType',
    'MAN_COLLNAME': 'CollisionTypeName',
    'RELJCT1': 'Junction1',
    'RELJCT1NAME': 'Junction1Name',
    'RELJCT2': 'Junction2',
    'RELJCT2NAME': 'Junction2Name',
    'TYP_INT': 'IntersectionType',
    'TYP_INTNAME': 'IntersectionTypeName',
    'REL_ROAD': 'RoadRelation',
    'REL_ROADNAME': 'RoadRelationName',
    'WRK_ZONE': 'WorkZone',
    'WRK_ZONENAME': 'WorkZoneName',
    'LGT_COND': 'LightCondition',
    'LGT_CONDNAME': 'LightConditionName',
    'WEATHER': 'Weather',
    'WEATHERNAME': 'WeatherName',
    'SCH_BUS': 'SchoolBus',
    'SCH_BUSNAME': 'SchoolBusName',
    'RAIL': 'Rail',
    'RAILNAME': 'RailName',
    'NOT_HOUR': 'NotificationHour',
    'NOT_HOURNAME': 'NotificationHourName',
    'NOT_MIN': 'NotificationMinute',
    'NOT_MINNAME': 'NotificationMinuteName',
    'ARR_HOUR': 'ArrivalHour',
    'ARR_HOURNAME': 'ArrivalHourName',
    'ARR_MIN': 'ArrivalMinute',
    'ARR_MINNAME': 'ArrivalMinuteName',
    'HOSP_HR': 'HospitalHour',
    'HOSP_HRNAME': 'HospitalHourName',
    'HOSP_MN': 'HospitalMinute',
    'HOSP_MNNAME': 'HospitalMinuteName',
    'FATALS': 'Fatalities'
}, inplace=True)

# %%
# NaN Werte in der Tabelle accident.csv
nan_counts = df.isna().sum().sum()
nan_counts_per_column = df.isna().sum()
print(nan_counts_per_column[nan_counts_per_column > 0])
# Out:
# TWAY_ID2        29337
# MILEPTNAME       5614
# WRK_ZONENAME    38400
# dtype: int64

# %%
df.describe()
# Out:
#               STATE        ST_CASE          PEDS    PERNOTMVIT      VE_TOTAL  \
# count  39221.000000   39221.000000  39221.000000  39221.000000  39221.000000
# mean      27.082583  271723.956273      0.243467      0.253283      1.583029
# std       16.497124  164851.845938      0.617775      0.635309      0.845585
# min        1.000000   10001.000000      0.000000      0.000000      1.000000
# 25%       12.000000  121850.000000      0.000000      0.000000      1.000000
# 50%       26.000000  260919.000000      0.000000      0.000000      1.000000
# 75%       42.000000  420579.000000      0.000000      0.000000      2.000000
# max       56.000000  560118.000000     73.000000     73.000000     50.000000
#
#            VE_FORMS      PVH_INVL       PERSONS       PERMVIT        COUNTY  \
# count  39221.000000  39221.000000  39221.000000  39221.000000  39221.000000
# mean       1.542566      0.040463      2.198006      2.188190     91.931669
# ...

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro Bundesstaat
state_counts = df['STATENAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 3))
state_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Bundesstaat')
plt.xlabel('Bundesstaat')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle mit Fußgängern
peds_counts = df['PEDS'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(10, 3))
peds_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle mit Fußgängern')
plt.xlabel('Anzahl der Fußgänger')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle mit nicht motorisierten Personen
pernotmvit_counts = df['PERNOTMVIT'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(10, 3))
pernotmvit_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle mit nicht motorisierten Personen')
plt.xlabel('Anzahl der nicht motorisierten Personen')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf der Anzahl der beteiligten Fahrzeuge
ve_total_counts = df['VE_TOTAL'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(10, 3))
ve_total_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf der Anzahl der beteiligten Fahrzeuge')
plt.xlabel('Anzahl der beteiligten Fahrzeuge')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf der Anzahl der Fahrzeugformulare
ve_forms_counts = df['VE_FORMS'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(10, 3))
ve_forms_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf der Anzahl der Fahrzeugformulare')
plt.xlabel('Anzahl der Fahrzeugformulare')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf der Anzahl der beteiligten Fahrzeuge
pvh_invl_counts = df['PVH_INVL'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(10, 3))
pvh_invl_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf der Anzahl der beteiligten Fahrzeuge')
plt.xlabel('Anzahl der beteiligten Fahrzeuge')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf der Anzahl der Personen
persons_counts = df['PERSONS'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(10, 3))
persons_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf der Anzahl der Personen')
plt.xlabel('Anzahl der Personen')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle mit motorisierten Personen
permvit_counts = df['PERMVIT'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(10, 3))
permvit_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle mit motorisierten Personen')
plt.xlabel('Anzahl der motorisierten Personen')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro County
county_counts = df['COUNTYNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
county_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro County')
plt.xlabel('County')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro Stadt
city_counts = df['CITYNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
city_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Stadt')
plt.xlabel('Stadt')
plt.ylabel('Anzahl der Unfälle')
plt.show()
# Out:
# /Users/raphaelkach/Library/Caches/pypoetry/virtualenvs/raphael-kach-abgabe-ml-aoNiLWIF-py3.12/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Anzahl der Unfälle pro Monat
month_counts = df['MONTHNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
month_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Monat')
plt.xlabel('Monat')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro Tag
day_counts = df['DAYNAME'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
day_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Tag')
plt.xlabel('Tag')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro Wochentag
day_week_counts = df['DAY_WEEK'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
day_week_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Wochentag')
plt.xlabel('Wochentag')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro Jahr
year_counts = df['YEAR'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(10, 6))
year_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Jahr')
plt.xlabel('Jahr')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro Stunde
hour_counts = df['HOUR'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
hour_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Stunde')
plt.xlabel('Stunde')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro Stunde
hour_counts = df['HOURNAME'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
hour_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Stunde')
plt.xlabel('Stunde')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro Minute
minute_counts = df['MINUTE'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
minute_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Minute')
plt.xlabel('Minute')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro Minute
minute_counts = df['MINUTENAME'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
minute_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Minute')
plt.xlabel('Minute')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro TWAY_ID
tway_id_counts = df['TWAY_ID'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
tway_id_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro TWAY_ID')
plt.xlabel('TWAY_ID')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro Route
route_counts = df['ROUTE'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
route_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Route')
plt.xlabel('Route')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro ROUTENAME
route_name_counts = df['ROUTENAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
route_name_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro ROUTENAME')
plt.xlabel('ROUTENAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf RUR_URB
rur_urb_counts = df['RUR_URBNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
rur_urb_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf RUR_URB')
plt.xlabel('RUR_URB')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf RUR_URBNAME
rur_urb_counts = df['RUR_URBNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
rur_urb_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf RUR_URBNAME')
plt.xlabel('RUR_URBNAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf FUNC_SYS
func_sys_counts = df['FUNC_SYSNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
func_sys_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf FUNC_SYS')
plt.xlabel('FUNC_SYS')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Diagramm für FUNC_SYSNAME
func_sys_counts.plot(kind='bar', figsize=(12, 6))
plt.title('Anzahl der Unfälle basierend auf FUNC_SYSNAME')
plt.xlabel('FUNC_SYSNAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle basierend auf RD_OWNER
rd_owner_counts = df['RD_OWNERNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
rd_owner_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf RD_OWNER')
plt.xlabel('RD_OWNER')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf RD_OWNERNAME
rd_owner_counts = df['RD_OWNERNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
rd_owner_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf RD_OWNERNAME')
plt.xlabel('RD_OWNERNAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf NHSNAME
nhs_counts = df['NHSNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
nhs_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf NHSNAME')
plt.xlabel('NHSNAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf NHSNAME
nhs_counts = df['NHS'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
nhs_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf NHS')
plt.xlabel('NHS')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf SP_JUR
sp_jur_counts = df['SP_JURNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
sp_jur_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf SP_JUR')
plt.xlabel('SP_JUR')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro MILEPT
milept_counts = df['MILEPT'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
milept_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro MILEPT')
plt.xlabel('MILEPT')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro MILEPTNAME
milept_name_counts = df['MILEPTNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
milept_name_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro MILEPTNAME')
plt.xlabel('MILEPTNAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf HARM_EV
harm_ev_counts = df['HARM_EVNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
harm_ev_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf HARM_EV')
plt.xlabel('HARM_EV')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Diagramm für HARM_EVNAME
harm_ev_counts.plot(kind='bar', figsize=(12, 6))
plt.title('Anzahl der Unfälle basierend auf HARM_EVNAME')
plt.xlabel('HARM_EVNAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf MAN_COLLNAME
man_coll_counts = df['MAN_COLL'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
man_coll_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf MAN_COLL')
plt.xlabel('MAN_COLL')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf MAN_COLLNAME
man_coll_counts = df['MAN_COLLNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
man_coll_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf MAN_COLLNAME')
plt.xlabel('MAN_COLLNAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf RELJCT1
reljct1_counts = df['RELJCT1'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
reljct1_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf RELJCT1')
plt.xlabel('RELJCT1')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf RELJCT1NAME
reljct1_name_counts = df['RELJCT1NAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
reljct1_name_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf RELJCT1NAME')
plt.xlabel('RELJCT1NAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf RELJCT2
reljct2_counts = df['RELJCT2'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
reljct2_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf RELJCT2')
plt.xlabel('RELJCT2')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle basierend auf RELJCT2NAME
reljct2_name_counts = df['RELJCT2NAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
reljct2_name_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf RELJCT2NAME')
plt.xlabel('RELJCT2NAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf TYP_INT
typ_int_counts = df['TYP_INTNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
typ_int_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf TYP_INT')
plt.xlabel('TYP_INT')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf REL_ROAD
rel_road_counts = df['REL_ROADNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
rel_road_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf REL_ROAD')
plt.xlabel('REL_ROAD')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf WRK_ZONE
wrk_zone_counts = df['WRK_ZONE'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
wrk_zone_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf WRK_ZONE')
plt.xlabel('WRK_ZONE')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf WRK_ZONENAME
wrk_zone_name_counts = df['WRK_ZONENAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
wrk_zone_name_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf WRK_ZONENAME')
plt.xlabel('WRK_ZONENAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf den Lichtverhältnissen
lgt_cond_counts = df['LGT_CONDNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
lgt_cond_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf den Lichtverhältnissen')
plt.xlabel('Lichtverhältnisse')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf den Wetterbedingungen
weather_counts = df['WEATHERNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
weather_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf den Wetterbedingungen')
plt.xlabel('Wetterbedingungen')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf SCH_BUS
sch_bus_counts = df['SCH_BUS'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
sch_bus_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf SCH_BUS')
plt.xlabel('SCH_BUS')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf RAIL
rail_counts = df['RAIL'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
rail_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf RAIL')
plt.xlabel('RAIL')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf RAILNAME
rail_name_counts = df['RAILNAME'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
rail_name_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf RAILNAME')
plt.xlabel('RAILNAME')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro Benachrichtigungsstunde
not_hour_counts = df['NOT_HOUR'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
not_hour_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Benachrichtigungsstunde')
plt.xlabel('Benachrichtigungsstunde')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Diagramm für NOT_HOURNAME
not_hourname_counts = df['NOT_HOURNAME'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
not_hourname_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Benachrichtigungsstunde')
plt.xlabel('Benachrichtigungsstunde')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro Benachrichtigungsminute
not_min_counts = df['NOT_MIN'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
not_min_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Benachrichtigungsminute')
plt.xlabel('Benachrichtigungsminute')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Diagramm für NOT_MINNAME
not_minname_counts = df['NOT_MINNAME'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
not_minname_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Benachrichtigungsminute')
plt.xlabel('Benachrichtigungsminute')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro Ankunftsstunde
arr_hour_counts = df['ARR_HOUR'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
arr_hour_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Ankunftsstunde')
plt.xlabel('Ankunftsstunde')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
# Anzahl der Unfälle pro Ankunftsstunde (ARR_HOURNAME)
arr_hourname_counts = df['ARR_HOURNAME'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
arr_hourname_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Ankunftsstunde (ARR_HOURNAME)')
plt.xlabel('Ankunftsstunde')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro Ankunftsminute
arr_min_counts = df['ARR_MIN'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
arr_min_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Ankunftsminute')
plt.xlabel('Ankunftsminute')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro Ankunftsminute (ARR_MINNAME)
arr_minname_counts = df['ARR_MINNAME'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
arr_minname_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Ankunftsminute (ARR_MINNAME)')
plt.xlabel('Ankunftsminute')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro Krankenhausstunde
hosp_hr_counts = df['HOSP_HR'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
hosp_hr_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Krankenhausstunde')
plt.xlabel('Krankenhausstunde')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro Krankenhausstunde (HOSP_HRNAME)
hosp_hrname_counts = df['HOSP_HRNAME'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
hosp_hrname_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Krankenhausstunde (HOSP_HRNAME)')
plt.xlabel('Krankenhausstunde')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro Krankenhausminute
hosp_mn_counts = df['HOSP_MN'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
hosp_mn_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Krankenhausminute')
plt.xlabel('Krankenhausminute')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle pro Krankenhausminute (HOSP_MNNAME)
hosp_mnname_counts = df['HOSP_MNNAME'].value_counts().sort_index()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
hosp_mnname_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle pro Krankenhausminute (HOSP_MNNAME)')
plt.xlabel('Krankenhausminute')
plt.ylabel('Anzahl der Unfälle')
plt.show()

# %%
import matplotlib.pyplot as plt

# Anzahl der Unfälle basierend auf der Anzahl der Todesfälle
fatal_counts = df['FATALS'].value_counts()

# Balkendiagramm erstellen
plt.figure(figsize=(12, 6))
fatal_counts.plot(kind='bar')
plt.title('Anzahl der Unfälle basierend auf der Anzahl der Todesfälle')
plt.xlabel('Anzahl der Todesfälle')
plt.ylabel('Anzahl der Unfälle')
plt.show()
